# %% [markdown]
# # Name-Aditya Bakshi
# Topic/Project- Basic Analysis of Netflix Data Using Libraries Such as-1)Pandas
#                                                                       2)Numpy
#                                                                       3)Seaborn
#                                                                       4)Pyplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("D:\\netflix_titles.csv")

# %% [markdown]
# # Printing database

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Displaying Size and Shape of Data

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # Performing the Operations On Data

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
df_copy=df.copy()

# %%
df_copy
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_copy=df.copy()

df_copy.drop(['director','cast','date_added'],axis=1,inplace=True)

df_copy
# Out:
#      show_id     type                  title        country  release_year  \
# 0         s1    Movie   Dick Johnson Is Dead  United States          2020
# 1         s2  TV Show          Blood & Water   South Africa          2021
# 2         s3  TV Show              Ganglands            NaN          2021
# 3         s4  TV Show  Jailbirds New Orleans            NaN          2021
# 4         s5  TV Show           Kota Factory          India          2021
# ...      ...      ...                    ...            ...           ...
# 8802   s8803    Movie                 Zodiac  United States          2007
# 8803   s8804  TV Show            Zombie Dumb            NaN          2018
# 8804   s8805    Movie             Zombieland  United States          2009
# 8805   s8806    Movie                   Zoom  United States          2006
# 8806   s8807    Movie                 Zubaan          India          2015
#
#      rating   duration                                          listed_in  \
# ...

# %%
import numpy as np
df_copy['country'].replace(np.NaN,'United States',inplace=True)

df_copy
# Out:
#      show_id     type                  title        country  release_year  \
# 0         s1    Movie   Dick Johnson Is Dead  United States          2020
# 1         s2  TV Show          Blood & Water   South Africa          2021
# 2         s3  TV Show              Ganglands  United States          2021
# 3         s4  TV Show  Jailbirds New Orleans  United States          2021
# 4         s5  TV Show           Kota Factory          India          2021
# ...      ...      ...                    ...            ...           ...
# 8802   s8803    Movie                 Zodiac  United States          2007
# 8803   s8804  TV Show            Zombie Dumb  United States          2018
# 8804   s8805    Movie             Zombieland  United States          2009
# 8805   s8806    Movie                   Zoom  United States          2006
# 8806   s8807    Movie                 Zubaan          India          2015
#
#      rating   duration                                          listed_in  \
# ...

# %%
df_copy['rating']
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
import numpy as np
df_copy['rating'].replace(np.NaN,'TV-MA',inplace=True)

df_copy
# Out:
#      show_id     type                  title        country  release_year  \
# 0         s1    Movie   Dick Johnson Is Dead  United States          2020
# 1         s2  TV Show          Blood & Water   South Africa          2021
# 2         s3  TV Show              Ganglands  United States          2021
# 3         s4  TV Show  Jailbirds New Orleans  United States          2021
# 4         s5  TV Show           Kota Factory          India          2021
# ...      ...      ...                    ...            ...           ...
# 8802   s8803    Movie                 Zodiac  United States          2007
# 8803   s8804  TV Show            Zombie Dumb  United States          2018
# 8804   s8805    Movie             Zombieland  United States          2009
# 8805   s8806    Movie                   Zoom  United States          2006
# 8806   s8807    Movie                 Zubaan          India          2015
#
#      rating   duration                                          listed_in  \
# ...

# %%
df_copy.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# country         831
# release_year      0
# rating            4
# duration          3
# listed_in         0
# description       0
# dtype: int64

# %%
df_copy
# Out:
#      show_id     type                  title        country  release_year  \
# 0         s1    Movie   Dick Johnson Is Dead  United States          2020
# 1         s2  TV Show          Blood & Water   South Africa          2021
# 2         s3  TV Show              Ganglands            NaN          2021
# 3         s4  TV Show  Jailbirds New Orleans            NaN          2021
# 4         s5  TV Show           Kota Factory          India          2021
# ...      ...      ...                    ...            ...           ...
# 8802   s8803    Movie                 Zodiac  United States          2007
# 8803   s8804  TV Show            Zombie Dumb            NaN          2018
# 8804   s8805    Movie             Zombieland  United States          2009
# 8805   s8806    Movie                   Zoom  United States          2006
# 8806   s8807    Movie                 Zubaan          India          2015
#
#      rating   duration                                          listed_in  \
# ...

# %% [markdown]
# # Visualizeing Data With the Help of Graphs using Library's such as Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(df_copy['rating'])
sns.countplot(df_copy['rating']).set_xticklabels(sns.countplot(df_copy['rating']).get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(13,13)
plt.title('Rating');
# Out:
# D:\Dataset\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Dataset\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Dataset\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Ratings of Movies and Shows

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='rating',hue='type',data=df_copy)
plt.title('Relation between Type and Rating of Movies and Shows Seperately')
plt.show();

# %% [markdown]
# # Relation between Type and Rating of Movies and Shows

# %%
sns.countplot(df_copy['type'])
fig.set_size_inches(10,10)
plt.title('Type');
# Out:
# D:\Dataset\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Relation between Movies and TV Shows

# %%
most_titles_produced = df_copy.groupby('country').count().sort_values('title',ascending=False).head(5)

most_titles_produced.reset_index(inplace=True)
most_titles_produced
# Out:
#           country  show_id  type  title  release_year  rating  duration  \
# 0   United States     3649  3649   3649          3649    3649      3646
# 1           India      972   972    972           972     972       972
# 2  United Kingdom      419   419    419           419     419       419
# 3           Japan      245   245    245           245     245       245
# 4     South Korea      199   199    199           199     199       199
#
#    listed_in  description
# 0       3649         3649
# 1        972          972
# 2        419          419
# 3        245          245
# 4        199          199

# %% [markdown]
# # country has the most number of titles produced

# %%
plt.bar(most_titles_produced.country,most_titles_produced.title);

# %% [markdown]
# # Netflix have more Movies or TV Shows

# %%
sns.countplot('type', data=df_copy);
# Out:
# D:\Dataset\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # What are the top 5 most popular ratings on Netflix

# %%
df_copy_rating = df_copy['rating'].value_counts()
df_copy_rating = pd.DataFrame(df_copy_rating).reset_index()
df_copy_rating.columns = ['rating','Nbr']
sns.barplot(x = 'rating',y = 'Nbr', data=df_copy_rating.head(5));

# %% [markdown]
# # Which are top 5 least popular genre on Netflix

# %%
genre=df_copy["listed_in"].value_counts().tail(5)
genre
# Out:
# Kids' TV, TV Action & Adventure, TV Dramas            1
# TV Comedies, TV Dramas, TV Horror                     1
# Children & Family Movies, Comedies, LGBTQ Movies      1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows    1
# Cult Movies, Dramas, Thrillers                        1
# Name: listed_in, dtype: int64

# %%
plt.figure(figsize=(10,4))
genre.plot(kind="bar",color="blue")
plt.title("5 Least Popular Genres on Netflix",size=20);

# %% [markdown]
# # Which were the top 5 years in number of titles released

# %%
top_5_year = df_copy.groupby('release_year').count().sort_values('title',ascending=False).head(5)

top_5_year.reset_index(inplace=True)
top_5_year
# Out:
#    release_year  show_id  type  title  country  rating  duration  listed_in  \
# 0          2018     1147  1147   1147     1147    1147      1147       1147
# 1          2017     1032  1032   1032     1032    1032      1031       1032
# 2          2019     1030  1030   1030     1030    1030      1030       1030
# 3          2020      953   953    953      953     953       953        953
# 4          2016      902   902    902      902     902       902        902
#
#    description
# 0         1147
# 1         1032
# 2         1030
# 3          953
# 4          902

# %%
plt.bar(top_5_year.release_year,top_5_year.title);

# %% [markdown]
# # Pie-chart for the Type: Movie and TV Shows

# %%
labels = ['Movie', 'TV show']
size = df['type'].value_counts()
colors = plt.cm.Wistia(np.linspace(0, 1, 2))
explode = [0, 0.1]
plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size,labels=labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Distribution of Type', fontsize = 25)
plt.legend()
plt.show()

# %% [markdown]
# # Pie-chart for Rating

# %%
df['rating'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.show()

# %% [markdown]
# # WordCloud

# %%
from wordcloud import WordCloud

# %% [markdown]
# # Most Word Used in Title

# %%
from wordcloud import WordCloud
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.title))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('country.png')
plt.show()

# %% [markdown]
# # Type Of Content

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.type))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('cast.png')
plt.show()

# %% [markdown]
# # Majority Word Used In Description

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.description))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('director.png')
plt.show()

# %% [markdown]
# # Categories

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.listed_in))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('category.png')
plt.show()
